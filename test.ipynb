# %%
#import library

import cv2
import matplotlib.pyplot as plt

# %%
#Reading Image

image = cv2.imread('hoop.jpg')

#BGR to RGB for plt
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Getting the height & Width of an image.

# %%
# Extract the height and width
h, w =image.shape[:2]

print(f"Height = {h} Width = {w}")
# Out:
# Height = 3685 Width = 5650

# %% [markdown]
# ### Getting the RGB values from the photo

# %%
(B,G,R) = image[100,100]

print(f"{R}, {G}, {B}")
# Out:
# 64, 66, 60

# %% [markdown]
# ### Show Image

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Getting a region of Interest

# %%
roi = image[100 : 500,200 : 700]

plt.imshow(roi)
plt.show()

# %% [markdown]
# ### Resize Image

# %%
resize = cv2.resize(image,(500,500))
plt.imshow(resize)

# %% [markdown]
# ### Resizing with Aspect Ratio

# %%
ratio = 500 / w

#tuple containing width and height
dim = (500, int(h*ratio))

#resizing
resizeAspect = cv2.resize(image,dim)
plt.imshow(resizeAspect)
plt.show()

# %% [markdown]
# ### Drawing a rectangle

# %%
output = image.copy()

rectangle = cv2.rectangle(output ,(800, 1900),(2000, 3000), (245, 66, 221), 15)

plt.imshow(rectangle)
plt.show()

# %% [markdown]
# ### Adding Text

# %%
rectangle = cv2.putText(rectangle ,'Basketball', (800,3300),cv2.FONT_HERSHEY_PLAIN,15,(245, 66, 221),15)

plt.imshow(rectangle)
plt.show()
